# %%
pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Using cached langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Using cached langgraph-1.1.9-py3-none-any.whl.metadata (8.0 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached langchain_protocol-0.0.12-py3-none-any.whl.metadata (1.8 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached langsmith-0.7.36-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.2)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_checkpoint-4.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_prebuilt-1.0.11-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading xxhash-3.7.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading orjson-3.11.8-cp311-cp311-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.4.22)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.13)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.46.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Using cached langchain-1.2.15-py3-none-any.whl (112 kB)
# Using cached langchain_core-1.3.2-py3-none-any.whl (542 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.1.9-py3-none-any.whl (173 kB)
# Using cached langgraph_checkpoint-4.0.2-py3-none-any.whl (51 kB)
# Using cached langgraph_prebuilt-1.0.11-py3-none-any.whl (36 kB)
# Using cached langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Using cached langsmith-0.7.36-py3-none-any.whl (381 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.0 MB/s  0:00:02 eta 0:00:010m
# Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (604 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached langchain_protocol-0.0.12-py3-none-any.whl (6.6 kB)
# Downloading orjson-3.11.8-cp311-cp311-macosx_15_0_arm64.whl (128 kB)
# Downloading ormsgpack-1.12.2-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.7.0-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.6/640.6 kB 732.6 kB/s  0:00:00eta 0:00:01
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, pyyaml, pydantic-core, ormsgpack, orjson, langchain-protocol, jsonpointer, h11, anyio, annotated-types, requests-toolbelt, pydantic, jsonpatch, httpcore, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25/25 [langchain]25 [langchain-core]
# Successfully installed annotated-types-0.7.0 anyio-4.13.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.2.15 langchain-core-1.3.2 langchain-protocol-0.0.12 langgraph-1.1.9 langgraph-checkpoint-4.0.2 langgraph-prebuilt-1.0.11 langgraph-sdk-0.3.13 langsmith-0.7.36 orjson-3.11.8 ormsgpack-1.12.2 pydantic-2.13.3 pydantic-core-2.46.3 pyyaml-6.0.3 requests-toolbelt-1.0.0 typing-inspection-0.4.2 uuid-utils-0.14.1 xxhash-3.7.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain_community
# Out:
# Collecting langchain_community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from langchain_community) (1.3.2)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Using cached langchain_classic-1.0.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.49-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/homebrew/lib/python3.11/site-packages (from langchain_community) (2.33.1)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain_community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain_community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Using cached pydantic_settings-2.14.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/homebrew/lib/python3.11/site-packages (from langchain_community) (0.7.36)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in /opt/homebrew/lib/python3.11/site-packages (from langchain_community) (2.4.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.13.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.0.12)
# Requirement already satisfied: packaging>=23.2.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (26.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.13.0)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.13)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl (501 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.4-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Using cached pydantic_settings-2.14.0-py3-none-any.whl (60 kB)
# Downloading sqlalchemy-2.0.49-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 1.3/2.2 MB 1.5 MB/s eta 0:00:01
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (1.3 MB/2.2 MB, attempt 1)
# Resuming download sqlalchemy-2.0.49-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB/2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 669.1 kB/s  0:00:01 eta 0:00:01
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl (85 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: SQLAlchemy, python-dotenv, propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain_community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [langchain_community]ngchain_community]
# Successfully installed SQLAlchemy-2.0.49 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 langchain-classic-1.0.4 langchain-text-splitters-1.1.2 langchain_community-0.4.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 propcache-0.4.1 pydantic-settings-2.14.0 python-dotenv-1.2.2 typing-inspect-0.9.0 yarl-1.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("speech.txt")
loader
text_docs = loader.load()
print(text_docs[0])
# Out:
# page_content='Speech is the use of the human voice as a medium for language. Spoken language combines vowel and consonant sounds to form units of meaning like words, which belong to a language's lexicon. There are many different intentional speech acts, such as informing, declaring, asking, persuading, directing; acts may vary in various aspects like enunciation, intonation, loudness, and tempo to convey meaning. Individuals may also unintentionally communicate aspects of their social position through speech, such as sex, age, place of origin, physiological and mental condition, education, and experiences.
#
# While normally used to facilitate communication with others, people may also use speech without the intent to communicate. Speech may nevertheless express emotions or desires; people talk to themselves sometimes in acts that are a development of what some psychologists (e.g., Lev Vygotsky) have maintained is the use of silent speech in an interior monologue to vivify and organize cognition, sometimes in the momentary adoption of a dual persona as self addressing self as though addressing another person. Solo speech can be used to memorize or to test one's memorization of things, and in prayer or in meditation.' metadata={'source': 'speech.txt'}

# %%
pip install langchain_community
# Out:
# Collecting langchain_community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=1.0.1 (from langchain_community)
#   Using cached langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Using cached langchain_classic-1.0.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Using cached sqlalchemy-2.0.49-cp314-cp314-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting PyYAML<7.0.0,>=5.3.0 (from langchain_community)
#   Using cached pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Using cached aiohttp-3.13.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_community)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Using cached pydantic_settings-2.14.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain_community)
#   Using cached langsmith-0.7.36-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchain_community) (2.4.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached frozenlist-1.8.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached multidict-6.7.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached propcache-0.4.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached yarl-1.23.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached langchain_protocol-0.0.12-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging>=23.2.0 in /Users/priya/Library/Python/3.14/lib/python/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (26.1)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached orjson-3.11.8-cp314-cp314-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached xxhash-3.7.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached zstandard-0.25.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2026.4.22)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached pydantic_core-2.46.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.32.5->langchain_community)
#   Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl.metadata (40 kB)
# Collecting urllib3<3,>=1.26 (from requests<3.0.0,>=2.32.5->langchain_community)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached aiohttp-3.13.5-cp314-cp314-macosx_11_0_arm64.whl (499 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.4-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-1.3.2-py3-none-any.whl (542 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached langsmith-0.7.36-py3-none-any.whl (381 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached multidict-6.7.1-cp314-cp314-macosx_11_0_arm64.whl (43 kB)
# Using cached pydantic-2.13.3-py3-none-any.whl (471 kB)
# Using cached pydantic_core-2.46.3-cp314-cp314-macosx_11_0_arm64.whl (2.0 MB)
# Using cached pydantic_settings-2.14.0-py3-none-any.whl (60 kB)
# Using cached pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl (173 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl (309 kB)
# Using cached idna-3.13-py3-none-any.whl (68 kB)
# Using cached sqlalchemy-2.0.49-cp314-cp314-macosx_11_0_arm64.whl (2.2 MB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (604 kB)
# Using cached yarl-1.23.0-cp314-cp314-macosx_11_0_arm64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached frozenlist-1.8.0-cp314-cp314-macosx_11_0_arm64.whl (49 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached langchain_protocol-0.0.12-py3-none-any.whl (6.6 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached orjson-3.11.8-cp314-cp314-macosx_15_0_arm64.whl (128 kB)
# Using cached propcache-0.4.1-cp314-cp314-macosx_11_0_arm64.whl (46 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached xxhash-3.7.0-cp314-cp314-macosx_11_0_arm64.whl (30 kB)
# Using cached zstandard-0.25.0-cp314-cp314-macosx_11_0_arm64.whl (640 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, urllib3, typing-extensions, tenacity, PyYAML, python-dotenv, propcache, orjson, mypy-extensions, multidict, marshmallow, jsonpointer, idna, httpx-sse, h11, frozenlist, charset_normalizer, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspection, typing-inspect, SQLAlchemy, requests, pydantic-core, langchain-protocol, jsonpatch, httpcore, anyio, aiosignal, requests-toolbelt, pydantic, httpx, dataclasses-json, aiohttp, pydantic-settings, langsmith, langchain-core, langchain-text-splitters, langchain-classic, langchain_community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44/44 [langchain_community]ommunity]lassic]
# Successfully installed PyYAML-6.0.3 SQLAlchemy-2.0.49 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 annotated-types-0.7.0 anyio-4.13.0 attrs-26.1.0 charset_normalizer-3.4.7 dataclasses-json-0.6.7 frozenlist-1.8.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 httpx-sse-0.4.3 idna-3.13 jsonpatch-1.33 jsonpointer-3.1.1 langchain-classic-1.0.4 langchain-core-1.3.2 langchain-protocol-0.0.12 langchain-text-splitters-1.1.2 langchain_community-0.4.1 langsmith-0.7.36 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 orjson-3.11.8 propcache-0.4.1 pydantic-2.13.3 pydantic-core-2.46.3 pydantic-settings-2.14.0 python-dotenv-1.2.2 requests-2.33.1 requests-toolbelt-1.0.0 tenacity-9.1.4 typing-extensions-4.15.0 typing-inspect-0.9.0 typing-inspection-0.4.2 urllib3-2.6.3 uuid-utils-0.14.1 xxhash-3.7.0 yarl-1.23.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("finalNLP.pdf")
docs = loader.load()
print(docs)
print(type(docs[0]))
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 0, 'page_label': '1'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 1, 'page_label': '2'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 2, 'page_label': '3'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 3, 'page_label': '4'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 4, 'page_label': '5'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 5, 'page_label': '6'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 6, 'page_label': '7'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 7, 'page_label': '8'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 8, 'page_label': '9'}, page_content=''), Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'finalNLP.pdf', 'total_pages': 10, 'page': 9, 'page_label': '10'}, page_content='')]
# <class 'langchain_core.documents.base.Document'>

# %%
pip install pypdf
# Out:
# Collecting pypdf
#   Using cached pypdf-6.10.2-py3-none-any.whl.metadata (7.1 kB)
# Using cached pypdf-6.10.2-py3-none-any.whl (336 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.10.2
# Note: you may need to restart the kernel to use updated packages.
